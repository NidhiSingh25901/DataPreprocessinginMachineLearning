# %% [markdown]
# <a href="https://colab.research.google.com/github/NidhiSingh25901/DataPreprocessinginMachineLearning/blob/main/14NumericalFeatureCategoricalTarget.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from sklearn.feature_selection import SelectKBest, f_classif, mutual_info_classif

# %%
df = pd.read_csv("/content/sample_data/california_housing_train.csv")

# %%
df.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value'],
#       dtype='object')

# %%
df = df.loc[:, ['housing_median_age', 'total_rooms', 'total_bedrooms', 'population', 'households', 'median_income', 'median_house_value']]

# %%
df
# Out:
#        housing_median_age  total_rooms  total_bedrooms  population  \
# 0                    15.0       5612.0          1283.0      1015.0
# 1                    19.0       7650.0          1901.0      1129.0
# 2                    17.0        720.0           174.0       333.0
# 3                    14.0       1501.0           337.0       515.0
# 4                    20.0       1454.0           326.0       624.0
# ...                   ...          ...             ...         ...
# 16995                52.0       2217.0           394.0       907.0
# 16996                36.0       2349.0           528.0      1194.0
# 16997                17.0       2677.0           531.0      1244.0
# 16998                19.0       2672.0           552.0      1298.0
# 16999                52.0       1820.0           300.0       806.0
#
#        households  median_income  median_house_value
# 0           472.0         1.4936             66900.0
# 1           463.0         1.8200             80100.0
# ...

# %%
x= df.iloc[:,0:6]
y=df.iloc[:,6]

# %%
y
# Out:
# 0         66900.0
# 1         80100.0
# 2         85700.0
# 3         73400.0
# 4         65500.0
#            ...
# 16995    111400.0
# 16996     79000.0
# 16997    103600.0
# 16998     85800.0
# 16999     94600.0
# Name: median_house_value, Length: 17000, dtype: float64

# %% [markdown]
# Feature Selection with Anova

# %%
selector = SelectKBest(f_classif, k=3)

# %%
selector.fit(x,y)
# Out:
# SelectKBest(k=3)

# %%
selector.transform(x)
# Out:
# array([[5.6120e+03, 4.7200e+02, 1.4936e+00],
#        [7.6500e+03, 4.6300e+02, 1.8200e+00],
#        [7.2000e+02, 1.1700e+02, 1.6509e+00],
#        ...,
#        [2.6770e+03, 4.5600e+02, 3.0313e+00],
#        [2.6720e+03, 4.7800e+02, 1.9797e+00],
#        [1.8200e+03, 2.7000e+02, 3.0147e+00]])

# %%
x.columns[selector.get_support()]
# Out:
# Index(['total_rooms', 'households', 'median_income'], dtype='object')

# %% [markdown]
# Feature Selection using Mutual Information

# %%
selector = SelectKBest(f_classif, k=5)

# %%
selector.fit(x,y)
# Out:
# SelectKBest(k=5)

# %%
selector.transform(x)
# Out:
# array([[5.6120e+03, 1.2830e+03, 1.0150e+03, 4.7200e+02, 1.4936e+00],
#        [7.6500e+03, 1.9010e+03, 1.1290e+03, 4.6300e+02, 1.8200e+00],
#        [7.2000e+02, 1.7400e+02, 3.3300e+02, 1.1700e+02, 1.6509e+00],
#        ...,
#        [2.6770e+03, 5.3100e+02, 1.2440e+03, 4.5600e+02, 3.0313e+00],
#        [2.6720e+03, 5.5200e+02, 1.2980e+03, 4.7800e+02, 1.9797e+00],
#        [1.8200e+03, 3.0000e+02, 8.0600e+02, 2.7000e+02, 3.0147e+00]])
